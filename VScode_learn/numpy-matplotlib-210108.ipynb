# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# 绘制多项式函数
func = np.poly1d(np.array([1,2,3,4]).astype(float))

# %%
x = np.linspace(-10,10,30)

# %%
y = func(x)

# %%
y
# Out:
# array([-8.26000000e+02, -6.57610152e+02, -5.13887162e+02, -3.92862930e+02,
#        -2.92569355e+02, -2.11038337e+02, -1.46301775e+02, -9.63915700e+01,
#        -5.93396203e+01, -3.31778261e+01, -1.59380868e+01, -5.65230227e+00,
#        -3.52371971e-01,  1.92980442e+00,  3.16232728e+00,  5.31329698e+00,
#         1.03508139e+01,  2.02429784e+01,  3.69578909e+01,  6.24636516e+01,
#         9.87283611e+01,  1.47720120e+02,  2.11407028e+02,  2.91757186e+02,
#         3.90738694e+02,  5.10319652e+02,  6.52468162e+02,  8.19152323e+02,
#         1.01234024e+03,  1.23400000e+03])

# %%
x
# Out:
# array([-10.        ,  -9.31034483,  -8.62068966,  -7.93103448,
#         -7.24137931,  -6.55172414,  -5.86206897,  -5.17241379,
#         -4.48275862,  -3.79310345,  -3.10344828,  -2.4137931 ,
#         -1.72413793,  -1.03448276,  -0.34482759,   0.34482759,
#          1.03448276,   1.72413793,   2.4137931 ,   3.10344828,
#          3.79310345,   4.48275862,   5.17241379,   5.86206897,
#          6.55172414,   7.24137931,   7.93103448,   8.62068966,
#          9.31034483,  10.        ])

# %%
print(func)
# Out:
#    3     2
# 1 x + 2 x + 3 x + 4

# %%
plt.plot(x,y)

# %%
plt.plot(x,y)
plt.xlabel('x')
plt.ylabel('y(x)')
plt.show()

# %%
func1 = func.deriv(m=1)

# %%
print(func1)
# Out:
#    2
# 3 x + 4 x + 3

# %%
x = np.linspace(-10,10,30)
y = func(x)
y1 = func1(x)

# %%
# 以两种不同风格绘制多项式函数及其导函数：红色圆形和绿色虚线
plt.plot(x,y,'ro',x,y1,'g--')
plt.xlabel('x')
plt.ylabel('y(x)')
plt.show()

# %%
# 绘图时可能会遇到图中有太多曲线的情况，而你希望分组绘制它们。这可以使用subplot函数完成。
func = np.poly1d(np.array([1,2,3,4]).astype(float))
x = np.linspace(-10,10,30)
y = func(x)
func1 = func.deriv(m=1)
y1 = func1(x)
func2 = func.deriv(m=2)
y2 = func2(x)

# %%
plt.subplot(311)
plt.plot(x,y,'r-')
plt.title('polynomial')
plt.subplot(312)
plt.plot(x,y1,'b^')
plt.title('first derivative')
plt.subplot(313)
plt.plot(x,y2,'go')
plt.title('second derivative')
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %%
"""使用matplotlib.finance包中的函数可以从雅虎
财经频道（http://finance.yahoo.com/）下载股价数据，并绘制成K线图（candlestick）。"""
# Out:
# '使用matplotlib.finance包中的函数可以从雅虎\n财经频道（http://finance.yahoo.com/）下载股价数据，并绘制成K线图（candlestick）。'

# %%
import matplotlib.pyplot as plt
from matplotlib.dates import DateFormatter
from matplotlib.dates import DayLocator
from matplotlib.dates import MonthLocator
import pandas as pd
import sys
from datetime import date, datetime
import mplfinance as mpf
import mpl_finance as mpf_
import pandas_datareader.data as webdata
from dateutil.relativedelta import relativedelta

# %%
today = date.today()
start = today-relativedelta(years=1)

# %%
start
# Out:
# datetime.date(2020, 1, 9)

# %%
today = today.strftime("%Y-%m-%d")
start = start.strftime("%Y-%m-%d")

# %%
alldays = DayLocator()
months = MonthLocator()
month_formatter = DateFormatter("%b %Y")

# %%
symbol = "DISH"
daily = pd.read_csv("data/SP500_NOV2019_Hist.csv", index_col=0,parse_dates=True)

# %%
daily.index.name = "Date"
daily.shape
# Out:
# (20, 5)

# %%
daily.head(3)
# Out:
#                Open     High      Low    Close     Volume
# Date
# 2019-11-01  3050.72  3066.95  3050.72  3066.91  510301237
# 2019-11-04  3078.96  3085.20  3074.87  3078.27  524848878
# 2019-11-05  3080.80  3083.95  3072.15  3074.62  585634570

# %%
daily.tail(3)
# Out:
#                Open     High      Low    Close     Volume
# Date
# 2019-11-26  3134.85  3142.69  3131.00  3140.52  986041660
# 2019-11-27  3145.49  3154.26  3143.41  3153.63  421853938
# 2019-11-29  3147.18  3150.30  3139.34  3140.98  286602291

# %%
mpf.plot(daily, type="candle")

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.xaxis.set_major_locator(months)
ax.xaxis.set_minor_locator(alldays)
ax.xaxis.set_major_formatter(month_formatter)
webdata.get_data_yahoo(symbol, start, today)
mpf.plot(daily)
# mpf_.candlestick_ohlc(ax=ax,quotes=daily, width=0.6, colorup='b', colordown='r')
fig.autofmt_xdate()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-43-5b05741dee23> in <module>
#       6 webdata.get_data_yahoo(symbol, start, today)
#       7 # mpf.plot(daily)
# ----> 8 mpf_.candlestick_ohlc(ax=ax,quotes=daily, width=0.6, colorup='b', colordown='r')
#       9 fig.autofmt_xdate()
#      10 plt.show()
#
# ~\AppData\Roaming\Python\Python38\site-packages\mpl_finance.py in candlestick_ohlc(ax, quotes, width, colorup, colordown, alpha)
#     247
#     248     """
# --> 249     return _candlestick(ax, quotes, width=width, colorup=colorup,
#     250                         colordown=colordown,
#     251                         alpha=alpha, ochl=False)
#
# ~\AppData\Roaming\Python\Python38\site-packages\mpl_finance.py in _candlestick(ax, quotes, width, colorup, colordown, alpha, ochl)
#     296             t, open, close, high, low = q[:5]
#     297         else:
# ...

# %%
import yfinance as yf

# %%
import datetime
import numpy as np
import matplotlib.dates as mdates
import pandas_datareader.data as webdata
import pandas as pd
import mplfinance as mpf
import matplotlib.pyplot as plt
import matplotlib
import yfinance as yf
from dateutil.relativedelta import relativedelta

# %%
def plotTicker(ticker, startdate, enddate, fillcolor):
    r = webdata.get_data_yahoo(ticker, startdate, enddate)
    print(r.head())
    mpf.plot(r, type='candle', mav=(2, 5, 10), volume=True)
    ###plot the relative strength indicator
    ###adjusted close removes the impacts of splits and dividends
    prices = r['Adj Close']

    ###plot the price and volume data

    ax.plot(r.index, prices, color=fillcolor, lw=2, label=ticker)
    ax.legend(loc='upper right', shadow=True, fancybox=True)  # shadow: 是否为图例边框添加阴影,fancybox: 是否将图例框的边角设为圆形
    '''
    #set the labels rotation and alignment
    for label in ax.get_xtickabels():    #get_xtickabels()也是用不了了，所以我直接注释了
        #To display date label slanting at 30 degreees
        label.set_rotation(30)
        label.set_horizontalalignment('right')
    '''
    ax.fmt_xdata = mdates.DateFormatter('%Y-%m-%d')

# %%
yf.pdr_override()  # 因为雅虎在中国受限制的原因，需要引入另一个模块，“yfinance”

startdate = datetime.datetime(2014, 4, 12)
enddate = datetime.datetime(2015, 5, 12)
# startdate = date.today()
# enddate = startdate-relativedelta(years=1)

# today = enddate = datetime.date.today()
plt.rcParams['font.sans-serif'] = ['SimHei']  # 允许中文
plt.rcParams['axes.unicode_minus'] = False  # 允许有坐标轴中的正负号
plt.rc('axes', grid=True)
plt.rc('grid', color='0.75', linestyle='-', linewidth=0.5)
rect = [0.4, 0.5, 0.8, 0.5]

fig = plt.figure(facecolor='white', figsize=(12, 11))

# axescolor = '#f6f6f6' #the axes background color
ax = fig.add_axes(rect, facecolor='#f6f6f6')  # left, bottom, width, height =[0.4,0.5,0.8,0.5]
ax.set_ylim(10, 800)

# plot the tickers now
plotTicker('BIDU', startdate, enddate, 'red')
plotTicker('GOOG', startdate, enddate, '#1066ee')
plotTicker('AMZN', startdate, enddate, '#506612')

plt.show()
# Out:
# [*********************100%***********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2014-04-11  148.500000  153.259995  147.229996  149.740005  149.740005
# 2014-04-14  153.360001  155.830002  150.279999  153.759995  153.759995
# 2014-04-15  153.809998  155.800003  147.250000  155.470001  155.470001
# 2014-04-16  159.289993  159.500000  152.100006  157.229996  157.229996
# 2014-04-17  156.270004  157.919998  152.759995  155.800003  155.800003
#
#              Volume
# Date
# 2014-04-11  4387800
# 2014-04-14  3776200
# 2014-04-15  5358200
# 2014-04-16  3847600
# 2014-04-17  3386500
# [*********************100%***********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2014-04-11  531.091858  538.521484  525.088379  529.147217  529.147217
# 2014-04-14  536.776306  542.610291  528.110046  531.061951  531.061951
# ...

# %%
qutoes = webdata.get_data_yahoo(symbol, start, today)
qutoes
# Out:
# [*********************100%***********************]  1 of 1 completed
#                  Open       High        Low      Close  Adj Close   Volume
# Date
# 2020-01-08  35.439999  35.630001  34.970001  35.490002  35.490002  1829100
# 2020-01-09  35.680000  35.700001  35.270000  35.580002  35.580002  1341600
# 2020-01-10  35.680000  35.740002  35.209999  35.360001  35.360001  1656800
# 2020-01-13  35.369999  36.119999  35.259998  36.060001  36.060001  1305700
# 2020-01-14  35.889999  36.849998  35.820000  36.590000  36.590000  2426500
# ...               ...        ...        ...        ...        ...      ...
# 2021-01-04  32.430000  32.669998  31.420000  31.530001  31.530001  5078500
# 2021-01-05  31.510000  32.040001  30.950001  31.469999  31.469999  3671700
# 2021-01-06  31.629999  32.099998  31.440001  31.820000  31.820000  4375600
# 2021-01-07  31.850000  32.700001  31.770000  32.419998  32.419998  3822500
# ...

# %%
qutoes = np.array(qutoes)

# %%
qutoes
# Out:
# array([[3.54399986e+01, 3.56300011e+01, 3.49700012e+01, 3.54900017e+01,
#         3.54900017e+01, 1.82910000e+06],
#        [3.56800003e+01, 3.57000008e+01, 3.52700005e+01, 3.55800018e+01,
#         3.55800018e+01, 1.34160000e+06],
#        [3.56800003e+01, 3.57400017e+01, 3.52099991e+01, 3.53600006e+01,
#         3.53600006e+01, 1.65680000e+06],
#        ...,
#        [3.16299992e+01, 3.20999985e+01, 3.14400005e+01, 3.18199997e+01,
#         3.18199997e+01, 4.37560000e+06],
#        [3.18500004e+01, 3.27000008e+01, 3.17700005e+01, 3.24199982e+01,
#         3.24199982e+01, 3.82250000e+06],
#        [3.25999985e+01, 3.31899986e+01, 3.24799995e+01, 3.31599998e+01,
#         3.31599998e+01, 4.34430000e+06]])

# %%
close = qutoes.T[4]

# %%
close
# Out:
# array([35.49000168, 35.58000183, 35.36000061, 36.06000137, 36.59000015,
#        36.65999985, 36.81999969, 36.79000092, 36.75      , 36.75      ,
#        36.88999939, 36.74000168, 36.75      , 36.75      , 36.75      ,
#        37.09999847, 36.75999832, 36.75      , 36.77999878, 37.93999863,
#        36.90000153, 36.77999878, 36.84999847, 39.47999954, 40.11000061,
#        40.18000031, 39.97000122, 41.29000092, 41.25      , 41.        ,
#        40.72999954, 38.36000061, 37.61999893, 36.31999969, 33.47999954,
#        33.52000046, 34.33000183, 32.81999969, 33.86999893, 31.43000031,
#        29.20999908, 24.93000031, 26.34000015, 23.57999992, 19.85000038,
#        21.59000015, 18.79000092, 20.87999916, 18.73999977, 21.87000084,
#        19.96999931, 18.14999962, 20.73999977, 20.63999939, 22.31999969,
#        20.97999954, 20.72999954, 19.98999977, 18.70000076, 18.95999908,
#        18.97999954, 21.11000061, 20.77000046, 21.78000069, 23.06999969,
# ...

# %%
len(close)
# Out:
# 254

# %%
plt.hist(close, int(np.sqrt(len(close))))
# Out:
# (array([ 6., 11., 11., 10., 13., 15., 20., 11., 21., 40., 34., 30., 23.,
#          2.,  7.]),
#  array([18.14999962, 19.69266637, 21.23533312, 22.77799988, 24.32066663,
#         25.86333338, 27.40600014, 28.94866689, 30.49133364, 32.0340004 ,
#         33.57666715, 35.1193339 , 36.66200066, 38.20466741, 39.74733416,
#         41.29000092]),
#  <BarContainer object of 15 artists>)

# %%
qutoes = webdata.get_data_yahoo(symbol, start, today)
qutoes = np.array(qutoes)
dates = qutoes.T[0]
volume = qutoes.T[5]
alldays = DayLocator()
months = MonthLocator()
month_formatter = DateFormatter("%b %Y")
fig = plt.figure()
ax = fig.add_subplot(111)
plt.semilogy(dates,volunes)
ax.xaxis.set_major_locator(months)
ax.xaxis.set_minor_locator(alldays)
ax.xaxis.set_major_formatter(month_formatter)
fig.autofmt_xdate()
plt.show()
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
# ：绘制股票收益率和成交量变化的散点图
"""得到的quotes数据存储在Python列表中。将其转化为NumPy数组并提取出收盘价和成交
量数据"""
qutoes = webdata.get_data_yahoo(symbol, start, today)
qutoes = np.array(qutoes)
dates = qutoes.T[4]
volume = qutoes.T[5]
ret = np.diff(close)/close[:-1]
volchange = np.diff(volume)/volume[:-1]
fig = plt.figure()
ax = fig.add_subplot(111)
ax.scatter(ret, volchange, c=ret * 100, s=volchange * 100, alpha=0.5)
ax.set_title('Close and volume returns')
ax.grid(True)
plt.show()
# Out:
# [*********************100%***********************]  1 of 1 completed
# D:\workApp\anaconda\lib\site-packages\matplotlib\collections.py:922: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor

# %%
qutoes = webdata.get_data_yahoo(symbol, start, today)
qutoes = np.array(qutoes)
dates = qutoes.T[0]
volume = qutoes.T[5]
alldays = DayLocator()
months = MonthLocator()
month_formatter = DateFormatter("%b %Y")
fig = plt.figure()
ax = fig.add_subplot(111)
plt.semilogy(dates,volunes)
ax.xaxis.set_major_locator(months)
ax.xaxis.set_minor_locator(alldays)
ax.xaxis.set_major_formatter(month_formatter)


dates = qutoes.T[4]
volume = qutoes.T[5]
ret = np.diff(close)/close[:-1]
volchange = np.diff(volume)/volume[:-1]
fig = plt.figure()
ax1 = fig.add_subplot(212)
ax1.scatter(ret, volchange, c=ret * 100, s=volchange * 100, alpha=0.5)
ax1.set_title('Close and volume returns')
ax1.grid(True)
fig.autofmt_xdate()
plt.show()
# Out:
# [*********************100%***********************]  1 of 1 completed
# D:\workApp\anaconda\lib\site-packages\matplotlib\collections.py:922: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor

# %%
quotes =webdata.get_data_yahoo(symbol, start, today)
quotes = np.array(quotes)
dates = quotes.T[0]
close = quotes.T[4]
alldays = DayLocator()
months = MonthLocator()
month_formatter = DateFormatter("%b %Y")
fig = plt.figure()
ax = fig.add_subplot(111)
ax.plot(dates, close)
plt.fill_between(dates, close.min(), close, where=close>close.mean(), facecolor="green",
alpha=0.4)
plt.fill_between(dates, close.min(), close, where=close<close.mean(),
facecolor="red", alpha=0.4)
ax.xaxis.set_major_locator(months)
ax.xaxis.set_minor_locator(alldays)
ax.xaxis.set_major_formatter(month_formatter)
ax.grid(True)
fig.autofmt_xdate()
plt.show()
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
from matplotlib import cm
from mpl_toolkits.mplot3d import Axes3D
# 将使用meshgrid函数创建一个二维的坐标网格。这将用于变量x和y的赋值
fig = plt.figure()
ax = fig.add_subplot(111,projection='3d')

z = x**2 + y**2
ax.plot_surface(x, y, z)

# %%
from matplotlib import cm
from mpl_toolkits.mplot3d import Axes3D
# 将使用meshgrid函数创建一个二维的坐标网格。这将用于变量x和y的赋值
fig = plt.figure()
ax = fig.add_subplot(111,projection='3d')
u = np.linspace(-1,1,100)
x, y = np.meshgrid(u, u)
z = x**2 + y**2
ax.plot_surface(x, y, z, rstride=4, cstride=4)

# %%
from matplotlib import cm
from mpl_toolkits.mplot3d import Axes3D
# 将使用meshgrid函数创建一个二维的坐标网格。这将用于变量x和y的赋值
fig = plt.figure()
ax = fig.add_subplot(111,projection='3d')

z = x**2 + y**2
ax.plot_surface(x, y, z, rstride=4, cstride=4, cmap=cm.YlGnBu_r)

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
u = np.linspace(-1,1,100)
x,y = np.meshgrid(u,u)
ax.contourf(x,y,z)
plt.show()

# %%
# 制作动画
import matplotlib.animation as animation

# %%
# 函数将被定期调用以更新屏幕上的内容。我们将随机更新两个数据集中的y坐标值
def update(data):
    circles.set_ydata(data[0])
    triangles.set_ydata(data[1])
    return circles, triangles

# %%
# NumPy生成随机数
def generate():
    while True:
        yield np.random.rand(2,N)

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
N = 10
x = np.random.rand(N)
y = np.random.rand(N)
z = np.random.rand(N)
circles, triangles, dots = ax.plot(x,'ro',y,'g^',z,'b.')
ax.set_ylim(0,1)
plt.axis('off')
anim = animation.FuncAnimation(fig, update, generate, interval=150)
plt.show()

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
N = 10
x = np.random.rand(N)
y = np.random.rand(N)
z = np.random.rand(N)
circles, triangles, dots = ax.plot(x,'ro',y,'g^',z,'b.')
ax.set_ylim(0,1)
plt.axis('off')
anim = animation.FuncAnimation(fig, update, generate, interval=150)
plt.show()
